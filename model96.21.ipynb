# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils import class_weight
from sklearn.model_selection import KFold, train_test_split
from tensorflow.keras import mixed_precision
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from PIL import Image
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from collections import Counter

# Define constants
IMG_SIZE = 224  # Image size (height and width)
BATCHSIZE = 32  # Batch size
EPOCHS = 150
data_dir = "data"  # Replace with your dataset path
l2_lambda = 0.01  # Keep increased L2 regularization

# Load dataset with shuffling (unbatched)
full_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=None,  # Load as individual images
    shuffle=True
)

# Get total number of images
total_images = sum(1 for _ in full_ds)
print(f"Total images: {total_images}")

# Preprocessing function (adjusted for MobileNetV2)
def preprocess_image(image, label):
    # Ensure image shape is (224, 224, 3)
    image = tf.ensure_shape(image, [IMG_SIZE, IMG_SIZE, 3])
    # Apply MobileNetV2 preprocessing
    image = tf.keras.applications.mobilenet_v2.preprocess_input(image)
    return image, label

# Apply preprocessing
full_ds = full_ds.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)

# Debug: Check shape of a sample before splitting
for image, label in full_ds.take(1):
    print(f"Sample shape before splitting: {image.shape}, Label shape: {label.shape}")

# Calculate split sizes
train_size = int(0.7 * total_images)  # 616 images
val_size = int(0.15 * total_images)   # 132 images
test_size = total_images - train_size - val_size  # 132 images

# Create datasets by splitting
train_ds = full_ds.take(train_size)
val_ds = full_ds.skip(train_size).take(val_size)
test_ds = full_ds.skip(train_size + val_size)

# Batch datasets after preprocessing
train_ds = train_ds.batch(BATCHSIZE, drop_remainder=False).cache().shuffle(buffer_size=train_size, seed=123).prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.batch(BATCHSIZE, drop_remainder=False).cache().prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.batch(BATCHSIZE, drop_remainder=False).cache().prefetch(tf.data.AUTOTUNE)

# Verify dataset sizes
print(f"Train size: {sum(1 for _ in train_ds.unbatch())}")
print(f"Validation size: {sum(1 for _ in val_ds.unbatch())}")
print(f"Test size: {sum(1 for _ in test_ds.unbatch())}")
# Out:
# Found 880 files belonging to 4 classes.
# Total images: 880
# Sample shape before splitting: (224, 224, 3), Label shape: ()
# Train size: 616
# Validation size: 132
# Test size: 132

# %%
# Load pretrained base model (MobileNetV2)
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = True
for layer in base_model.layers[:140]:  # Freeze first 140 layers
    layer.trainable = False

# %%
# Define model architecture
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, kernel_regularizer=tf.keras.regularizers.l2(l2_lambda))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
x = layers.ReLU()(x)
x = layers.Dense(128, kernel_regularizer=tf.keras.regularizers.l2(l2_lambda))(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(4, activation='softmax')(x)
model = keras.Model(inputs, outputs)

# %%
# Build the model with a dummy input to initialize variables
dummy_input = tf.zeros((1, IMG_SIZE, IMG_SIZE, 3))
model(dummy_input)  # This ensures all variables are created
# Out:
# <tf.Tensor: shape=(1, 4), dtype=float32, numpy=array([[0.33505493, 0.18698499, 0.39412478, 0.08383527]], dtype=float32)>

# %%
# Compile model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=5e-5),  # Reduced learning rate
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Define callbacks
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,  # Reduced patience
    restore_best_weights=True
)
lr_scheduler = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6
)
callbacks = [early_stopping, lr_scheduler]

# %%
class_weights_dict = {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0}  # Update with actual weights if needed

# %%
# Train model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    class_weight=class_weights_dict
)
# Out:
# Epoch 1/150
# 20/20 [==============================] - 6s 149ms/step - loss: 7.8207 - accuracy: 0.2565 - val_loss: 7.4475 - val_accuracy: 0.2045 - lr: 5.0000e-05
# Epoch 2/150
# 20/20 [==============================] - 2s 117ms/step - loss: 7.5868 - accuracy: 0.3425 - val_loss: 7.2767 - val_accuracy: 0.3030 - lr: 5.0000e-05
# Epoch 3/150
# 20/20 [==============================] - 2s 109ms/step - loss: 7.5455 - accuracy: 0.3490 - val_loss: 7.0001 - val_accuracy: 0.5076 - lr: 5.0000e-05
# Epoch 4/150
# 20/20 [==============================] - 2s 109ms/step - loss: 7.3992 - accuracy: 0.3571 - val_loss: 6.8763 - val_accuracy: 0.5985 - lr: 5.0000e-05
# Epoch 5/150
# 20/20 [==============================] - 2s 109ms/step - loss: 7.2246 - accuracy: 0.4399 - val_loss: 6.7939 - val_accuracy: 0.5909 - lr: 5.0000e-05
# Epoch 6/150
# 20/20 [==============================] - 2s 109ms/step - loss: 7.1508 - accuracy: 0.4448 - val_loss: 6.6622 - val_accuracy: 0.6818 - lr: 5.0000e-05
# Epoch 7/150
# 20/20 [==============================] - 2s 110ms/step - loss: 7.1108 - accuracy: 0.4578 - val_loss: 6.5444 - val_accuracy: 0.7273 - lr: 5.0000e-05
# Epoch 8/150
# 20/20 [==============================] - 2s 108ms/step - loss: 6.9706 - accuracy: 0.4903 - val_loss: 6.5194 - val_accuracy: 0.7273 - lr: 5.0000e-05
# Epoch 9/150
# 20/20 [==============================] - 2s 109ms/step - loss: 6.7970 - accuracy: 0.5308 - val_loss: 6.4263 - val_accuracy: 0.7879 - lr: 5.0000e-05
# Epoch 10/150
# 20/20 [==============================] - 2s 109ms/step - loss: 6.7589 - accuracy: 0.5422 - val_loss: 6.3691 - val_accuracy: 0.7727 - lr: 5.0000e-05
# Epoch 11/150
# 20/20 [==============================] - 2s 109ms/step - loss: 6.6516 - accuracy: 0.5860 - val_loss: 6.3073 - val_accuracy: 0.7879 - lr: 5.0000e-05
# Epoch 12/150
# 20/20 [==============================] - 2s 108ms/step - loss: 6.6179 - accuracy: 0.5860 - val_loss: 6.2562 - val_accuracy: 0.8106 - lr: 5.0000e-05
# Epoch 13/150
# 20/20 [==============================] - 3s 136ms/step - loss: 6.4527 - accuracy: 0.6282 - val_loss: 6.1833 - val_accuracy: 0.8106 - lr: 5.0000e-05
# Epoch 14/150
# 20/20 [==============================] - 3s 152ms/step - loss: 6.3756 - accuracy: 0.6721 - val_loss: 6.0863 - val_accuracy: 0.8258 - lr: 5.0000e-05
# Epoch 15/150
# 20/20 [==============================] - 2s 112ms/step - loss: 6.2925 - accuracy: 0.6542 - val_loss: 6.0425 - val_accuracy: 0.8182 - lr: 5.0000e-05
# Epoch 16/150
# 20/20 [==============================] - 2s 110ms/step - loss: 6.2371 - accuracy: 0.6899 - val_loss: 5.9886 - val_accuracy: 0.8409 - lr: 5.0000e-05
# Epoch 17/150
# 20/20 [==============================] - 2s 111ms/step - loss: 6.1869 - accuracy: 0.6997 - val_loss: 5.9406 - val_accuracy: 0.8333 - lr: 5.0000e-05
# Epoch 18/150
# 20/20 [==============================] - 2s 113ms/step - loss: 6.0673 - accuracy: 0.7289 - val_loss: 5.8856 - val_accuracy: 0.8561 - lr: 5.0000e-05
# Epoch 19/150
# 20/20 [==============================] - 2s 113ms/step - loss: 6.0654 - accuracy: 0.7143 - val_loss: 5.8185 - val_accuracy: 0.8712 - lr: 5.0000e-05
# Epoch 20/150
# 20/20 [==============================] - 2s 112ms/step - loss: 5.9787 - accuracy: 0.7256 - val_loss: 5.7829 - val_accuracy: 0.8561 - lr: 5.0000e-05
# Epoch 21/150
# 20/20 [==============================] - 2s 111ms/step - loss: 5.9113 - accuracy: 0.7646 - val_loss: 5.7306 - val_accuracy: 0.8561 - lr: 5.0000e-05
# Epoch 22/150
# 20/20 [==============================] - 2s 112ms/step - loss: 5.8622 - accuracy: 0.7711 - val_loss: 5.7386 - val_accuracy: 0.8258 - lr: 5.0000e-05
# Epoch 23/150
# 20/20 [==============================] - 2s 110ms/step - loss: 5.8350 - accuracy: 0.7597 - val_loss: 5.6549 - val_accuracy: 0.8712 - lr: 5.0000e-05
# Epoch 24/150
# 20/20 [==============================] - 2s 112ms/step - loss: 5.7257 - accuracy: 0.7955 - val_loss: 5.5927 - val_accuracy: 0.8561 - lr: 5.0000e-05
# Epoch 25/150
# 20/20 [==============================] - 2s 113ms/step - loss: 5.6573 - accuracy: 0.7987 - val_loss: 5.5633 - val_accuracy: 0.8788 - lr: 5.0000e-05
# Epoch 26/150
# 20/20 [==============================] - 2s 110ms/step - loss: 5.6263 - accuracy: 0.8377 - val_loss: 5.4989 - val_accuracy: 0.8939 - lr: 5.0000e-05
# Epoch 27/150
# 20/20 [==============================] - 2s 111ms/step - loss: 5.5494 - accuracy: 0.8312 - val_loss: 5.4494 - val_accuracy: 0.9167 - lr: 5.0000e-05
# Epoch 28/150
# 20/20 [==============================] - 2s 111ms/step - loss: 5.5179 - accuracy: 0.8149 - val_loss: 5.3951 - val_accuracy: 0.9167 - lr: 5.0000e-05
# Epoch 29/150
# 20/20 [==============================] - 2s 111ms/step - loss: 5.4427 - accuracy: 0.8506 - val_loss: 5.3786 - val_accuracy: 0.9015 - lr: 5.0000e-05
# Epoch 30/150
# 20/20 [==============================] - 2s 110ms/step - loss: 5.4177 - accuracy: 0.8588 - val_loss: 5.3592 - val_accuracy: 0.9242 - lr: 5.0000e-05
# Epoch 31/150
# 20/20 [==============================] - 2s 111ms/step - loss: 5.3686 - accuracy: 0.8701 - val_loss: 5.2568 - val_accuracy: 0.9242 - lr: 5.0000e-05
# Epoch 32/150
# 20/20 [==============================] - 2s 112ms/step - loss: 5.2986 - accuracy: 0.8718 - val_loss: 5.2270 - val_accuracy: 0.9470 - lr: 5.0000e-05
# Epoch 33/150
# 20/20 [==============================] - 2s 116ms/step - loss: 5.2290 - accuracy: 0.8896 - val_loss: 5.2099 - val_accuracy: 0.9318 - lr: 5.0000e-05
# Epoch 34/150
# 20/20 [==============================] - 2s 110ms/step - loss: 5.2123 - accuracy: 0.8750 - val_loss: 5.1387 - val_accuracy: 0.9470 - lr: 5.0000e-05
# Epoch 35/150
# 20/20 [==============================] - 2s 111ms/step - loss: 5.1532 - accuracy: 0.8896 - val_loss: 5.1035 - val_accuracy: 0.9394 - lr: 5.0000e-05
# Epoch 36/150
# 20/20 [==============================] - 2s 111ms/step - loss: 5.1234 - accuracy: 0.8880 - val_loss: 5.0512 - val_accuracy: 0.9470 - lr: 5.0000e-05
# Epoch 37/150
# 20/20 [==============================] - 2s 120ms/step - loss: 5.0588 - accuracy: 0.8994 - val_loss: 5.0091 - val_accuracy: 0.9545 - lr: 5.0000e-05
# Epoch 38/150
# 20/20 [==============================] - 2s 116ms/step - loss: 5.0264 - accuracy: 0.8977 - val_loss: 4.9812 - val_accuracy: 0.9470 - lr: 5.0000e-05
# Epoch 39/150
# 20/20 [==============================] - 2s 121ms/step - loss: 4.9750 - accuracy: 0.9140 - val_loss: 4.9179 - val_accuracy: 0.9470 - lr: 5.0000e-05
# Epoch 40/150
# 20/20 [==============================] - 2s 111ms/step - loss: 4.9258 - accuracy: 0.9188 - val_loss: 4.8647 - val_accuracy: 0.9545 - lr: 5.0000e-05
# Epoch
- val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 108/150
# 20/20 [==============================] - 2s 110ms/step - loss: 2.5403 - accuracy: 0.9984 - val_loss: 2.6463 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 109/150
# 20/20 [==============================] - 2s 108ms/step - loss: 2.5126 - accuracy: 1.0000 - val_loss: 2.5915 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 110/150
# 20/20 [==============================] - 2s 105ms/step - loss: 2.4841 - accuracy: 1.0000 - val_loss: 2.6015 - val_accuracy: 0.9545 - lr: 5.0000e-05
# Epoch 111/150
# 20/20 [==============================] - 2s 108ms/step - loss: 2.4560 - accuracy: 1.0000 - val_loss: 2.5727 - val_accuracy: 0.9545 - lr: 5.0000e-05
# Epoch 112/150
# 20/20 [==============================] - 2s 109ms/step - loss: 2.4312 - accuracy: 1.0000 - val_loss: 2.5495 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 113/150
# 20/20 [==============================] - 2s 108ms/step - loss: 2.4039 - accuracy: 1.0000 - val_loss: 2.4824 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 114/150
# 20/20 [==============================] - 2s 108ms/step - loss: 2.3743 - accuracy: 1.0000 - val_loss: 2.4561 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 115/150
# 20/20 [==============================] - 2s 105ms/step - loss: 2.3465 - accuracy: 1.0000 - val_loss: 2.4680 - val_accuracy: 0.9470 - lr: 5.0000e-05
# Epoch 116/150
# 20/20 [==============================] - 2s 105ms/step - loss: 2.3208 - accuracy: 0.9984 - val_loss: 2.4723 - val_accuracy: 0.9470 - lr: 5.0000e-05
# Epoch 117/150
# 20/20 [==============================] - 2s 108ms/step - loss: 2.2925 - accuracy: 0.9968 - val_loss: 2.4070 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 118/150
# 20/20 [==============================] - 2s 111ms/step - loss: 2.2709 - accuracy: 0.9968 - val_loss: 2.3582 - val_accuracy: 0.9545 - lr: 5.0000e-05
# Epoch 119/150
# 20/20 [==============================] - 2s 109ms/step - loss: 2.2447 - accuracy: 0.9984 - val_loss: 2.3377 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 120/150
# 20/20 [==============================] - 2s 110ms/step - loss: 2.2163 - accuracy: 1.0000 - val_loss: 2.3275 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 121/150
# 20/20 [==============================] - 2s 112ms/step - loss: 2.1895 - accuracy: 1.0000 - val_loss: 2.2998 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 122/150
# 20/20 [==============================] - 2s 108ms/step - loss: 2.1668 - accuracy: 1.0000 - val_loss: 2.2377 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 123/150
# 20/20 [==============================] - 2s 109ms/step - loss: 2.1415 - accuracy: 0.9968 - val_loss: 2.2219 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 124/150
# 20/20 [==============================] - 2s 112ms/step - loss: 2.1149 - accuracy: 0.9984 - val_loss: 2.2061 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 125/150
# 20/20 [==============================] - 2s 109ms/step - loss: 2.0878 - accuracy: 0.9984 - val_loss: 2.1827 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 126/150
# 20/20 [==============================] - 2s 109ms/step - loss: 2.0641 - accuracy: 1.0000 - val_loss: 2.1596 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 127/150
# 20/20 [==============================] - 2s 109ms/step - loss: 2.0354 - accuracy: 1.0000 - val_loss: 2.1306 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 128/150
# 20/20 [==============================] - 2s 109ms/step - loss: 2.0122 - accuracy: 1.0000 - val_loss: 2.0926 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 129/150
# 20/20 [==============================] - 2s 111ms/step - loss: 1.9885 - accuracy: 1.0000 - val_loss: 2.0907 - val_accuracy: 0.9545 - lr: 5.0000e-05
# Epoch 130/150
# 20/20 [==============================] - 2s 109ms/step - loss: 1.9638 - accuracy: 1.0000 - val_loss: 2.0712 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 131/150
# 20/20 [==============================] - 2s 108ms/step - loss: 1.9408 - accuracy: 1.0000 - val_loss: 2.0302 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 132/150
# 20/20 [==============================] - 2s 108ms/step - loss: 1.9122 - accuracy: 1.0000 - val_loss: 2.0253 - val_accuracy: 0.9545 - lr: 5.0000e-05
# Epoch 133/150
# 20/20 [==============================] - 2s 109ms/step - loss: 1.8917 - accuracy: 0.9984 - val_loss: 2.0005 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 134/150
# 20/20 [==============================] - 2s 109ms/step - loss: 1.8659 - accuracy: 1.0000 - val_loss: 1.9597 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 135/150
# 20/20 [==============================] - 2s 106ms/step - loss: 1.8423 - accuracy: 0.9984 - val_loss: 2.0331 - val_accuracy: 0.9470 - lr: 5.0000e-05
# Epoch 136/150
# 20/20 [==============================] - 2s 109ms/step - loss: 1.8199 - accuracy: 1.0000 - val_loss: 1.9478 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 137/150
# 20/20 [==============================] - 2s 108ms/step - loss: 1.7989 - accuracy: 1.0000 - val_loss: 1.9015 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 138/150
# 20/20 [==============================] - 2s 109ms/step - loss: 1.7737 - accuracy: 1.0000 - val_loss: 1.9095 - val_accuracy: 0.9470 - lr: 5.0000e-05
# Epoch 139/150
# 20/20 [==============================] - 2s 105ms/step - loss: 1.7497 - accuracy: 1.0000 - val_loss: 1.9063 - val_accuracy: 0.9470 - lr: 5.0000e-05
# Epoch 140/150
# 20/20 [==============================] - 2s 108ms/step - loss: 1.7255 - accuracy: 1.0000 - val_loss: 1.8573 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 141/150
# 20/20 [==============================] - 2s 109ms/step - loss: 1.7069 - accuracy: 0.9984 - val_loss: 1.8138 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 142/150
# 20/20 [==============================] - 2s 108ms/step - loss: 1.6853 - accuracy: 1.0000 - val_loss: 1.8009 - val_accuracy: 0.9545 - lr: 5.0000e-05
# Epoch 143/150
# 20/20 [==============================] - 2s 109ms/step - loss: 1.6615 - accuracy: 0.9984 - val_loss: 1.7777 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 144/150
# 20/20 [==============================] - 2s 112ms/step - loss: 1.6387 - accuracy: 1.0000 - val_loss: 1.7487 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 145/150
# 20/20 [==============================] - 2s 109ms/step - loss: 1.6157 - accuracy: 1.0000 - val_loss: 1.7279 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 146/150
# 20/20 [==============================] - 2s 108ms/step - loss: 1.5950 - accuracy: 1.0000 - val_loss: 1.7011 - val_accuracy: 0.9697 - lr: 5.0000e-05
# Epoch 147/150
# 20/20 [==============================] - 2s 106ms/step - loss: 1.5734 - accuracy: 1.0000 - val_loss: 1.7255 - val_accuracy: 0.9545 - lr: 5.0000e-05
# Epoch 148/150
# 20/20 [==============================] - 2s 112ms/step - loss: 1.5508 - accuracy: 1.0000 - val_loss: 1.6810 - val_accuracy: 0.9545 - lr: 5.0000e-05
# Epoch 149/150
# 20/20 [==============================] - 2s 109ms/step - loss: 1.5298 - accuracy: 1.0000 - val_loss: 1.6338 - val_accuracy: 0.9621 - lr: 5.0000e-05
# Epoch 150/150
# 20/20 [==============================] - 2s 110ms/step - loss: 1.5111 - accuracy: 0.9968 - val_loss: 1.5967 - val_accuracy: 0.9697 - lr: 5.0000e-05

# %%
score = model.evaluate(test_ds)
# Out:
# 5/5 [==============================] - 0s 70ms/step - loss: 1.6145 - accuracy: 0.9621

# %%
plt.figure(figsize=(12, 4))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.legend()

plt.show()

# %%
import numpy as np
from sklearn.metrics import precision_score, f1_score, classification_report

# Get predictions on the test dataset
y_pred_prob = model.predict(test_ds)
y_pred = np.argmax(y_pred_prob, axis=-1)

# Extract true labels from test_ds
y_true = np.concatenate([y for x, y in test_ds], axis=0)

print("Classification Report:")
print(classification_report(y_true, y_pred))
print("Precision:", precision_score(y_true, y_pred, average='weighted'))
print("F1 Score:", f1_score(y_true, y_pred, average='weighted'))
# Out:
# 5/5 [==============================] - 1s 78ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        34
#            1       0.97      0.97      0.97        32
#            2       1.00      0.89      0.94        28
#            3       0.93      1.00      0.96        38
#
#     accuracy                           0.96       132
#    macro avg       0.97      0.96      0.96       132
# weighted avg       0.96      0.96      0.96       132
#
# Precision: 0.9637841832963784
# F1 Score: 0.9619095179162054

# %%
misclassified_images = []
true_labels = []
pred_labels = []

for batch_images, batch_labels in test_ds:
    # Get predictions for the batch
    predictions = model.predict(batch_images, verbose=0)
    predicted_labels = np.argmax(predictions, axis=1)

    # Identify misclassified indices
    mismatches = np.where(predicted_labels != batch_labels.numpy())[0]

    for idx in mismatches:
        img = (batch_images[idx].numpy() + 1) / 2  # Convert from [-1, 1] to [0, 1]
        misclassified_images.append(img)
        true_labels.append(class_names[int(batch_labels[idx].numpy())])
        pred_labels.append(class_names[predicted_labels[idx]])

# Plot misclassified images (up to 20 for visualization)
plt.figure(figsize=(15, 15))
num_to_show = min(len(misclassified_images), 20)

for i in range(num_to_show):
    plt.subplot(4, 5, i + 1)  # 4 rows × 5 columns
    plt.imshow(misclassified_images[i])
    plt.title(f"True: {true_labels[i]}\nPred: {pred_labels[i]}", color='red')
    plt.axis("off")

if len(misclassified_images) == 0:
    print("🎉 Great job! No misclassifications in the whole test set!")

plt.tight_layout()
plt.show()
